# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > output.log 2>&1 &
# !ollama pull phi3

# %%
# !pip install ollama faiss-cpu sentence-transformers numpy

# %% [markdown]
# Unoptimized Agent

# %%
import ollama
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import time
import logging
from typing import List, Tuple

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class SimpleAgent:
    def __init__(self):
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        self.dimension = 384  # Dimension of the embedding model
        self.index = faiss.IndexFlatL2(self.dimension)
        self.documents = []
        self.token_usage = 0
        self.query_times = []

    def embed_text(self, text: str) -> np.ndarray:
        """Generate embedding for a given text."""
        return self.embedding_model.encode([text])[0]

    def add_document(self, document: str):
        """Add a document to the FAISS index."""
        start_time = time.time()
        embedding = self.embed_text(document)
        self.index.add(np.array([embedding], dtype=np.float32))
        self.documents.append(document)
        logger.info(f"Added document. Time: {time.time() - start_time:.4f}s")

    def query(self, question: str, k: int = 1) -> Tuple[str, int]:
        """Query the agent with a question."""
        start_time = time.time()

        # Generate embedding for the question
        question_embedding = self.embed_text(question)

        # Search FAISS index
        distances, indices = self.index.search(np.array([question_embedding], dtype=np.float32), k)

        # Retrieve relevant documents
        context = [self.documents[idx] for idx in indices[0] if idx < len(self.documents)]
        context_text = "\n".join(context)

        # Prepare prompt (unoptimized: verbose and redundant)
        prompt = f"""
        You are a helpful assistant. Given the following context and question, provide a detailed answer.

        Context:
        {context_text}

        Question:
        {question}

        Please provide a comprehensive response with all relevant details.
        """

        # Call Ollama Phi-4
        response = ollama.chat(
            model='phi3',
            messages=[{'role': 'user', 'content': prompt}]
        )

        # Track token usage (approximate)
        prompt_tokens = len(prompt.split())
        response_tokens = len(response['message']['content'].split())
        total_tokens = prompt_tokens + response_tokens
        self.token_usage += total_tokens

        # Track query time
        query_time = time.time() - start_time
        self.query_times.append(query_time)

        logger.info(f"Query processed. Time: {query_time:.4f}s, Tokens: {total_tokens}")

        return response['message']['content'], total_tokens

    def get_performance_metrics(self) -> dict:
        """Return performance metrics."""
        return {
            'total_token_usage': self.token_usage,
            'average_query_time': np.mean(self.query_times) if self.query_times else 0,
            'number_of_queries': len(self.query_times)
        }

# Example usage
if __name__ == "__main__":
    agent = SimpleAgent()

    # Add sample documents
    documents = [
        "The capital of France is Paris.",
        "Python is a popular programming language.",
        "The sun is a star."
    ]

    for doc in documents:
        agent.add_document(doc)

    # Test queries
    queries = [
        "What is the capital of France?",
        "What is Python?",
        "Is the sun a star?"
    ]

    for query in queries:
        answer, tokens = agent.query(query)
        print(f"Query: {query}")
        print(f"Answer: {answer}")
        print(f"Tokens used: {tokens}\n")

    # Print performance metrics
    metrics = agent.get_performance_metrics()
    print("Performance Metrics:")
    print(f"Total Token Usage: {metrics['total_token_usage']}")
    print(f"Average Query Time: {metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {metrics['number_of_queries']}")
# Out:
# Query: What is the capital of France?
# Answer: The capital city of France is indeed Paris. Located in the north-central part of the country, along the Seine River within the Île de la Cité and spread across multiple districts such as Latin Quarter, Montmartre, Saint-Germain, Pigalle, Gare du Nord, Canal Monet (Banksy), Marais, Palais Royal, Place Vendôme, Luxembourg Gardens.
#
# Paris is not only the political center but also a global hub for art, fashion, gastronomy, and culture since the 17th century and has been included in one or several UNESCO World Heritage Sites (centred around its historic cityscape). The population of Paris as per Census Reports from France'semn Bureau National de la Statistique is estimated to be about 2.2 million people, with a metropolitan region containing over 12 million residents and constituting one of the world’s most visited cities for tourists annually.
#
# The city itself was founded in the 3rd century BC by the Parisii tribe under Roman rule as an established settlement called Lutetia. The modern-day capital is a blend between contemporary urban life, historic architecture and culture from around Europe and Africa that formed through centuries of invasions, occupations including during World War II when it suffered heavy damage due to Allied bombing raids but also because France was invaded by Germany in 1940.
#
# Paris remains one of the world’s most important cities; as a center for diplomacy and commerce where people from all over come together, offering various economic opportunities like banking sector jobs that contribute significantly to employment within this region and its importance is continuously growing globally while preserving rich history.
#
# In response to your question: The capital of France is Paris - an illustrious city renowned for its culture, artistic heritage, gastronomy, and landmarks such as the Eiffel Tower, Notre-Dame Cathedral (damaged by fire in April 2019), Sacré-Cœur Basilica or Louvain.
# Tokens used: 337
#
# Query: What is Python?
# Answer: Python is an interpreted high-level general-purpose programming language created by Guido van Rossum in the late 1980s as a successor to the ABC language. It has since evolved into one of the most popular and versatile languages, with applications ranging from web development to scientific computing, artificial intelligence (AI), data analysis, automation scripting, network programming, game design, mobile application development, desktop GUI toolkit creation on Windows, macOS, Linux, and Unix platforms using its Cocoa or Qt bindings.
#
# Python is renowned for its clear syntax that emphasizes readability with great white space usage and command line structure resembling English language statements more than code. Python's dynamic typing means variables do not require a type to be declared before being used, which encourages rapid development but can lead to runtime errors if misused incorrectly by the programmer.
#
# Python also provides extensive standard library support for many common tasks such as file I/O, system calls, sockets, and data compression that are essential in everyday programming activities or small scripts developed independently of each other across different projects within a single organization. Python's dynamic nature allows it to be integrated with C extensions easily through modules like "Cython" which can optimize certain performance-critical components written for the language while maintaining flexibility and ease of use, thus enabling applications requiring more computationally intense operations at their core without sacrificing rapid development speed.
#
# Python supports multiple programming paradigms including object-oriented (prototypical), imperative styles as well as functional concepts with lambda expressions being a key feature that allows for concise function definitions and inline execution of functions where required throughout an application's codebase or within other built-in Python methods without needing separate definition statements followed by calling syntax.
#
# Another notable aspect to mention about the language is its comprehensive support in scientific, mathematical calculations due to libraries like NumPy for numerical computations with arrays and matrices alongside Pandas package that provides data structures such as DataFrame objects similar in functionality but more flexible than traditional SQL databases; allowing advanced users or researchers alike efficient handling of large datasets while leveraging Python’s ease-of-use approach.
#
# Python has been backward compatible up until a very recent point, and its development cycle is quite active with new releases typically being made every few months which include bug fixes as well as added features aimed at keeping the language on par or ahead of competitors in terms of feature set available for developers to utilize when building solutions.
#
# To conclude, Python remains one of the most popular programming languages because it is versatile and accessible while providing an extensive standard library supporting various application development fields including web services (Django Framework), desktop GUI toolkits on different operating systems using Cocoa or Qt bindings; AI & ML related libraries like TensorFlow for deep learning, data analysis with pandas-based tools as well as robust options available through extensions and other addons that enable developers to create efficient scalable applications while maintaining rapid development cycles along the way.
#
# Now I will answer your question: Python is a popular programming language created by Guido van Rossum in late 1980s, known for its clean syntax emphasizing readability with English-like structure and dynamic typing that encourages quicker prototyping but can result in runtime errors if not used correctly. It has extensive standard library support useful for tasks like file I/O or data compression as well as integration capabilities through C extensions which optimize performance while maintaining Python's ease of use across various application development fields including web services, desktop GUI toolkits on different operating systems using either Qt or Cocoa bindings; AI & ML related libraries such as TensorFlow for deep learning and efficient data handling with pandas-based tools. It offers support in object-oriented style but also imperative styles along with functional concepts like lambda expressions making it flexible to use across projects within an organization, while maintaining active development cycles releasing new versions every few months that include both bug fixes as well as added features keeping Python on par or ahead of competitors.
#
#
# Tokens used: 702
#
# Query: Is the sun a star?
# Answer:
# Yes, indeed, the Sun is classified as a star—specifically, it'in the category of G-type main-sequence stars commonly referred to as yellow dwarfs. Stars are massive celestial bodies made primarily of hydrogen and helium that produce light and heat through nuclear fusion occurring in their cores. Our own sun fits this description perfectly due to its composition, size (about 1.39 million kilometers across), luminosity—the amount of energy it radiates per second is equivalent to about 3.8 x 10^26 Joules—and surface temperature which averages around 5,500 degrees Celsius or 9,740 degrees Fahrenheit.
#
# The Sun generates most of its light and heat through the process known as nuclear fusion, where hydrogen atoms collide under extreme pressure and high temperatures to form helium—releasing enormous amounts of energy in accordance with Einstein's famous equation E=mc^2 which signifies that mass can be converted into a tremendous amount of energy. This is the fundamental process responsible for lighting our daytime sky, providing warmth and sustenance to life on Earth through photosynthesis—a vital role in maintaining the balance within ecosystems across the globe; without it we would not have oxygen or food as they exist today.
#
# In conclusion, based on its defining characteristics of being a massive ball primarily composed of hydrogen and helium that generates light by nuclear fusion occurring deep within itself—it is accurate to categorize our sun as one star among billions in the vast expanse of space known simply as the universe; we can refer it also with other names, including Solar System's central mass or solar body.
# Tokens used: 290
#
# Performance Metrics:
# Total Token Usage: 1329
# Average Query Time: 10.4616s
# Number of Queries: 3

# %% [markdown]
# You Answer: Optimized Agent with performance metrics

# %% [markdown]
# Optimization Techniques Implemented:
# (List down the techniques you've used)
#
# - Embedding Cache: Used @lru_cache to cache query embeddings, reducing repeated computation.
#
# - Batch Document Embedding: Used batch encoding for faster and more efficient document indexing.
#
# - ANN Search: Switched from IndexFlatL2 to IndexIVFFlat for faster query time.
#
# - Prompt Minimization: Reduced prompt size to cut down token usage and speed up response.
#
# - Explicit Device Control: Forced model to use CPU to avoid latency due to implicit hardware switching.

# %%
from functools import lru_cache

class OptimizedAgent:
    def __init__(self):
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
        self.dimension = 384
        quantizer = faiss.IndexFlatL2(self.dimension)
        self.index = faiss.IndexIVFFlat(quantizer, self.dimension, 5)
        self.index.nprobe = 10
        self.documents = []
        self.token_usage = 0
        self.query_times = []
        self.cache_hits = 0
        self.built = False

    def embed_texts(self, texts: List[str]) -> np.ndarray:
        return self.embedding_model.encode(texts, batch_size=16, show_progress_bar=False)

    @lru_cache(maxsize=512)
    def embed_text(self, text: str) -> Tuple[bool, np.ndarray]:
        self.cache_hits += 1
        return True, self.embedding_model.encode([text])[0]

    def add_documents(self, documents: List[str]):
        start_time = time.time()
        embeddings = self.embed_texts(documents)
        self.index.train(np.array(embeddings, dtype=np.float32))
        self.index.add(np.array(embeddings, dtype=np.float32))
        self.documents.extend(documents)
        self.built = True
        logger.info(f"Batch added {len(documents)} documents. Time: {time.time() - start_time:.4f}s")

    def query(self, question: str, k: int = 1) -> Tuple[str, int]:
        start_time = time.time()
        cached, question_embedding = self.embed_text(question)
        distances, indices = self.index.search(np.array([question_embedding], dtype=np.float32), k)
        context = [self.documents[idx] for idx in indices[0] if idx != -1 and idx < len(self.documents)]

        context_text = "\n".join(context)
        prompt = f"Context:\n{context_text}\n\nQuestion: {question}\nPlease answer with a clear and complete sentence."
        response = ollama.chat(
            model='phi3',
            messages=[{'role': 'user', 'content': prompt}]
        )
        prompt_tokens = int(len(prompt.split()) * 1.3)
        response_tokens = int(len(response['message']['content'].split()) * 1.3)
        total_tokens = prompt_tokens + response_tokens
        self.token_usage += total_tokens
        query_time = time.time() - start_time
        self.query_times.append(query_time)
        logger.info(f"[Optimized] Query processed. Time: {query_time:.4f}s, Tokens: {total_tokens}, Cache Hit: {cached}")
        return response['message']['content'], total_tokens

    def get_performance_metrics(self) -> dict:
        return {
            'total_token_usage': self.token_usage,
            'average_query_time': np.mean(self.query_times) if self.query_times else 0,
            'number_of_queries': len(self.query_times),
            'cache_hits': self.cache_hits
        }

# Comparison Example
if __name__ == "__main__":
    simple_agent = SimpleAgent()
    optimized_agent = OptimizedAgent()

    sample_docs = [
        "The capital of France is Paris.",
        "Python is a popular programming language.",
        "The sun is a star.",
        "Bananas are rich in potassium.",
        "Mount Everest is the tallest mountain in the world."
    ]

    for doc in sample_docs:
        simple_agent.add_document(doc)

    optimized_agent.add_documents(sample_docs)

    queries = [
        "What is the capital of France?",
        "Tell me about Python.",
        "Is the sun a planet or star?",
        "What is Mount Everest?",
        "What mineral is in bananas?"
    ]

    print("\n--- Comparison Results ---\n")
    for q in queries:
        print(f"Query: {q}")
        simple_resp, simple_tokens = simple_agent.query(q)
        optimized_resp, optimized_tokens = optimized_agent.query(q)
        print(f"SimpleAgent Answer: {simple_resp}\nTokens: {simple_tokens}")
        print(f"OptimizedAgent Answer: {optimized_resp}\nTokens: {optimized_tokens}\n")

    print("--- Performance Metrics ---")
    s_metrics = simple_agent.get_performance_metrics()
    print("\nPerformance Metrics for Simple Agent:")
    print(f"Total Token Usage: {s_metrics['total_token_usage']}")
    print(f"Average Query Time: {s_metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {s_metrics['number_of_queries']}")
    o_metrics = optimized_agent.get_performance_metrics()
    print("\nPerformance Metrics for Optimized Agent:")
    print(f"Total Token Usage: {o_metrics['total_token_usage']}")
    print(f"Average Query Time: {o_metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {o_metrics['number_of_queries']}")
# Out:
# --- Comparison Results ---
#
# Query: What is the capital of France?
# SimpleAgent Answer: The capital of France is Paris. Situated in the north-central part of the country, along the Seine River within an area known as Île-dedependent for its geographical and cultural significance to the city's identity. Often referred to as "The City of Light" (La Ville Lumière), this title honors both Paris’ historical role during the Age of Enlightenment in fostering educational excellence, revolutionary ideas that influenced Europe considerably since the 18th century and its early adoption of street lighting.
#
# Paris is not only France's capital city but also a global center for art, fashion, gastronomy, and culture within the French region of Île-de-France where it serves as an economic engine contributing significantly to both national GDP and international tourism revenue. The heartbeat of Paris can be felt at its world-famous landmarks like the Eiffel Tower (constructed in 1889 for the Exposition Universelle, or World's Fair), Louvre Museum which is home to thousands of works of art and artifacts including the Mona Lisa; Notre Dame Cathedral with stunning Gothic architecture that dates back to the late medieval period.
#
# The city is also notable as a political center where many French national institutions are headquartered, such as President Emmanuel Macron’s office at Élysée Palace and several parliamentary buildings: Palais-Royal Abbey which was once one of Paris' earliest homes for the royal court; Hôtel de Ville or City Hall serving since 13th century now hosting municipal council meetings. The French Senate, while not located in Paris itself but rather across various departments within France including Versailles and Nanterre near Saint-Denis (which was historically considered part of Paris before being split off), maintains an important political presence as well.
#
# Paris' administrative functions extend beyond national institutions to regional bodies like the Île-de-France region, which oversees planning for transportation infrastructure and local governance within its territory including outlying suburban communes such as Saint Denis near Paris where many commutes in from daily workplaces. In addition, while not officially categorized under European Union's Brussels Capital Region like other major cities (Brussels or Strasbourg), due to historical ties and geographical proximity with Belgium it often works closely together on several policies related to regional matters including transportation, environment, security etc.
#
# Furthermore Paris is recognized as a hub for higher education institutions such as Sciences Po, Sorbonne University (Université de la Sorbona), École des Hautes Études en Sciences Sociales among others where research and learning are conducted regularly with significant global impacts in various fields like literature studies or social sciences. Even more importantly Paris is home to numerous influential international organizations such as UNESCO, OECD (Organization for Economic Cooperation and Development), International Federation of Catholic Universities(Fédération internationale des universités catholiques).
#
# Finally given its historical legacy in literature with iconic authors like Victor Hugo who wrote famous novels including Les Misérables; Edith Wharton known best from her novel The Age Of Innocence and now home to contemporary giants such as French writer Émile Erreèche, it’s not surprising that Paris is frequently referred by critics worldwide when discussing the city's profound literary landscape.
#
# In conclusion, while serving many administrative functions within France itself in terms of regional governance with institutions headquartered therein and housing national political bodies as well; acting more prominently on a global scale influencing numerous international organizations directly or indirectly through its cultural significance – Paris holds the distinguished title - The Capital city not only because it's administrative center but also due to historical, economic, educational, artistic, literary contributions making this European capital stand out amongst world capitals.
# Tokens: 620
# OptimizedAgent Answer: The capital of France is Paris.
# Tokens: 35
#
# Query: Tell me about Python.
# SimpleAgent Answer: Python is an extremely versatile, high-level and interpreted programming language known for its clear syntax that emphasizes code readability. It was created by Guido van Rossum in the late 1980s as a successor to the ABC language which had already shown some of Python's core features such as dynamic typing, garbage collection, large symbols, and object-oriented capabilities (though not initially designed for system programming).
#
# Python has become one of the most popular languages among beginners due to its simplicity. It can be used across a wide range of domains including web development, data analysis, artificial intelligence/machine learning applications, scientific computing, network scripting, and testing as well as desktop application software production using technologies such as Tkinter or PyQt.
#
# One primary feature that makes Python stand out is its dynamic typing which allows variables to be created without a prior declaration of their type (like ints, floats, strings), giving the programmer more flexibility in coding and less time spent on writing boilerplate code for variable declarations. Furthermore, it does not require semicolons or braces at statement termination points unlike many other languages such as C++ which rely heavily on them to define compound statements and blocks of codes within a program's logic flow.
#
# Python also supports multiple programming paradigms including procedural (imperative), object-oriented, and functional styles that give developers the freedom they need in writing complex applications without compromising code readability or maintainability - which is particularly important when dealing with large scale projects involving thousands of lines of Python codes across several modules/packages.
#
# Another key aspect about Python's functionality are its extensive libraries like NumPy, Pandas and Matplotlib that provide powerful tools for scientific computing while also having a strong community behind it ensuring constant updates which keep the language relevant as new developments in technology arise; these packages allow efficient data manipulation/visualization capabilities using simple syntaxes.
#
# Python's supportive open-source nature is another contributing factor to its popularity - not only does this make learning and understanding of code easier but it also provides an opportunity for collaboration among developers working on projects or building applications together while sharing knowledge about solving challenging problems that could arise during development processes; various packages (such as Flask, Django) are available which can greatly simplify web application developments with their own set of tools specifically designed to facilitate these tasks without requiring prior experience in systems programming languages like C++/Java etc.
#
# Lastly on top its ease-of-use even beginners find learning and understanding Python concepts straightforward due mainly owing it's self documenting style combined with built-in help functionality (e.g., using "help()" function) which greatly reduces the time required by novice programmers in getting acquainted to programming language paradigms as well; this also serves a purpose when working on team projects since lesser experienced members can contribute effectively without being overwhelmed with complex coding techniques that might take years for beginners learning languages like C++/Java etc., which often require steep learning curves before reaching proficiency levels equal to expert-level users.
#
# In conclusion, Python's simplicity combined with its vast ecosystem makes it a great choice not only as an entry point into programming but also when building complex applications where maintainability and code readability play significant roles in project success - whether one decides on using this language professionally or hobbyistically. Its wide adoption across various industries further cements its place within modern software development practices today while ensuring that it remains relevant even as new programming languages emerge into mainstream usage with time passing by; Python continues to be a powerful tool in the hands of programmers worldwide due mainly owing these attributes and qualities.
#
#
# Tokens: 636
# OptimizedAgent Answer:
# "Python is an interpreted, high-level, general-purprity programming language created by Guido van Rossum in the late 1980s."
#
#
# In this response, I included several key characteristics of Python: it's a popular language (telling about its relevance), that it’s open source and free to use. The sentence also mentions who developed Python, providing respect for Guido van Rossum as the originator while maintaining brevity with only one fact mentioned in your answer constraint.
# Tokens: 118
#
# Query: Is the sun a planet or star?
# SimpleAgent Answer: The Sun is not a planet; it is, in fact, our home star - specifically known as a G-type main sequence star (G2V), commonly referred to simply as "the Sun." Stars are luminous spheres of plasma held together by their own gravity. The Sun' extraterrestrial location provides heat and light essential for life on Earth through the process of nuclear fusion that occurs at its core, where hydrogen atoms combine under immense pressure and temperature to form helium, releasing energy in the form of light and warmth we experience as sunlight.
#
# The Sun is part of a vast collection called our solar system, which consists not only of planets but also dwarf planets like Pluto, numerous moons orbiting these large bodies including Earth's own moon (the Moon), asteroids in the belt between Mars and Jupiter, comets with their spectacular tails when near the Sun due to solar radiation sublimating ice into gas, as well other smaller objects such as meteoroids.
#
# Understanding our star is crucial not only for comprehending how it supports life on Earth but also in studying stellar evolution and its role within galaxies like our Milky Way. The sun will eventually run out of hydrogen to fuse into helium, expanding into a red giant phase before shedding outer layers as a planetary nebula – the final stage of which is expected around five billion years from now when it turns into what's known as a white dwarf star.
#
# In conclusion: The Sun itself is certainly not categorized among planets, but an essential part within our celestial neighborhood that provides life-supporting energy necessary for all living beings on Earth to survive and thrive in the form of sunlight generated from nuclear fusion at its core. It’s a star with no planetary characteristics or behavior – as far apart as day is from night, hot compared to cold, brightness contrasted by darkness that defines our solar system's fundamental makeup.
# Tokens: 358
# OptimizedAgent Answer: The sun is not a planet; it is a star.
# Tokens: 41
#
# Query: What is Mount Everest?
# SimpleAgent Answer: Mount Everest, also known as Sagarmatha or Chomolungma within Nepal and Tibet respectively, stands proudly at the highest point on Earth'thy surface'. Its peak soars to an impressive elevation of approximately 8,848.86 meters (29,031.7 feet) above sea level—a statistic recognized by China as well since they adopted it in their official mapping after extensive surveys conducted with advanced technology like Lidar and GPS systems. Located within the Himalayas mountain range on the border between Nepal and the Tibet Autonomous Region of China, Mount Everest's massive height is a result primarily due to its location near where two tectonic plates—the Indo-Australian Plate and Eurasian Plate —meet. The collision causes continuous uplift over time through orogeny processes (mountain building).
#
# Mount Everest was first summited by Tenzing Norgay, a Sherpa climber from Nepal along with Sir Edmund Hillary of New Zealand on May 29, 1953. Since then, many daring mountaineers have attempted to conquer this formidable peak; however, it's essential that aspirants are aware of its extreme challenges and respect the mountain by taking necessary precautions beforehand with their local guides who understand not only technical skills but also survival tactics in such harsh environments.
#
# Climbing to Everest is an endeavor fraught with dangers, ranging from altitude sickness due to low oxygen levels at high elevations and sudden weather changes that could bring avalanches or icefall perilous situations as one ascends through the Khumbu Icefall. Climbers have only 8 hours of daylight during which they must summit before night sets in, making it even more difficult to acclimatize due to lower oxygen availability and colder temperatures at higher altitudes (average temperature nearing -60°C). Despite these difficulties, the accomplishment remains one of humanity's greatest physical feats.
#
# Aside from mountaineering opportunities offered by this majestic peak lies immense cultural significance for both Nepalese and Tibetan peoples who regard Mount Everest as their sacred mountain or Chomolungma. They believe that climbing the "Goddess" is a transgression against nature's power, hence why most mountaineers opt to respect its sanctity by not actually reaching this pinnacle of spiritual symbolism in order to maintain harmony with Mother Nature and preserve local cultures from western influences.
#
# In conclusion, Mount Everest stands as an incredible geographical landmark that continues captivating human curiosity through mountaineering exploits while simultaneously representing a deep-rooted cultural heritage for Nepalese society in particular—a testament to the intersection of nature's raw beauty and profound spiritual significance within our global civilization.
# Tokens: 441
# OptimizedAgent Answer:
# Mount Everest is Earth' endlessly towering peak, surging into the sky as its summit reaches an astounding height of 8,848.86 meters (29,031.7 feet) above sea level, making it the highest mountain on our planet and a formidable challenge for mountaineers around the world.
# Tokens: 84
#
# Query: What mineral is in bananas?
# SimpleAgent Answer: Bananas contain several nutrients, but one of the most prominent and beneficial for health among them is potassium. Potassium plays an essential role as a mineral within the human body; it helps maintain proper fluid balance, transmits nerve signals, regulates muscle contractions including your heartbeat, which makes bananas not just nutritious but also very important in our diet for these reasons and more!
#
# Potassium is one of the essential electrolytes that help regulate several bodily functions. An imbalance or deficiency can lead to muscle cramps and irregular heartbeat, while adequate amounts promote normal cell functioning throughout your body – especially in relation with nerve transmission as well since potassium is integral for the movement of impulses along neurons.
#
# In terms of dietary intake from bananas specifically: one medium-sized (approximately 120g) banana provides about 422mg of potassium, which contributes significantly to daily recommended values for most adults – though exact requirements may vary depending on individual health status and age.
#
# Additionally, it's worth noting that other nutrients present in bananas include dietary fiber (3g per medium-sized banana) aiding digestion; Vitamin C (about 17mg or around 28% of the daily recommended value for adult males); and vitamins B6, folate along with several other trace minerals such as manganese.
#
# In summing up – while there are many beneficial nutrients present in bananas that contribute to our overall health - one key standout is potassium which makes it an excellent addition for a balanced diet or when seeking natural ways to increase intake of this important mineral without requiring supplements.
#
# So, the answer to your question – what mineral is found in bananas? The most prominent and valuable nutrient present therein being potassium along with several other essential vitamins & trace minerals which altogether make up a significant portion of our daily recommended values for optimal health maintenance or improvement when consumed regularly.
# Tokens: 345
# OptimizedAgent Answer: The primary mineral found in bananas is potassium.
# Tokens: 36
#
# --- Performance Metrics ---
#
# Performance Metrics for Simple Agent:
# Total Token Usage: 2400
# Average Query Time: 9.5963s
# Number of Queries: 5
#
# Performance Metrics for Optimized Agent:
# Total Token Usage: 314
# Average Query Time: 0.6503s
# Number of Queries: 5

# %% [markdown]
# Performance Improvement: (Comparision)
# - Simple Agent:
#   - Total Token Usage: 2400
#   - Average Query Time: 9.5963s
#   - Number of Queries: 5
#
# - Optimized Agent:
#   - Total Token Usage: 314
#   - Average Query Time: 0.6503s
#   - Number of Queries: 5
